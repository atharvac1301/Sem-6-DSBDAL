# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('nba.csv')

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
# Remove the last row since it has all NAN values
df.drop(457, inplace=True)

df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
frequent_college = df['College'].value_counts().idxmax()
mean_salary = df['Salary'].median()

df['College'].fillna(frequent_college, inplace=True)
df['Salary'].fillna(mean_salary, inplace=True)

df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df.describe().astype(int)
# Out:
#        Number  Age  Weight    Salary
# count     457  457     457       457
# mean       17   26     221   4842684
# std        15    4      26   5165780
# min         0   19     161     30888
# 25%         5   24     200   1100602
# 50%        13   26     220   2869440
# 75%        25   30     240   6331404
# max        99   40     307  25000000

# %%
categorical_variables = ['Team']
quantitive_variables  = ['Name', 'Age', 'Position', 'College', 'Salary']

# %%
df.groupby(by=categorical_variables[0])['Salary'].describe()
# Out:
#                         count          mean           std        min  \
# Team
# Atlanta Hawks            15.0  4.860197e+06  5.194508e+06   525093.0
# Boston Celtics           15.0  4.225583e+06  3.036396e+06  1148640.0
# Brooklyn Nets            15.0  3.501898e+06  5.317817e+06   134215.0
# Charlotte Hornets        15.0  5.222728e+06  4.538601e+06   189455.0
# Chicago Bulls            15.0  5.785559e+06  6.251088e+06   525093.0
# Cleveland Cavaliers      15.0  7.455425e+06  7.484116e+06   111196.0
# Dallas Mavericks         15.0  4.746582e+06  5.030279e+06   525093.0
# Denver Nuggets           15.0  4.330974e+06  4.165468e+06   258489.0
# Detroit Pistons          15.0  4.477884e+06  4.668478e+06   111444.0
# Golden State Warriors    15.0  5.924600e+06  5.664282e+06   289755.0
# Houston Rockets          15.0  5.018868e+06  6.414749e+06   200600.0
# Indiana Pacers           15.0  4.450122e+06  4.584514e+06   211744.0
# ...
