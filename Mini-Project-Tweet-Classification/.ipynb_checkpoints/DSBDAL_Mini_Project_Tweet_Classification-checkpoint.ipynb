# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/31106_Atharva_Choudhari/DSBDAL/Tweet-Classification/data_science.csv")

# %%
tweets = df['tweet']

tweets_filtered = [tweets[i] for i in range(1, 100)]
tweets_filtered
# Out:
# ['"We need a paradigm shift from model-centric to data-centric ML development." Tobias Schaffrath Rosario shares the reasons why so many applied ML projects fail and proposes a solution  https://t.co/nf2y1HQ1NH',
#  'Using high-resolution satellite data and computer algorithms, scientists have revealed how gases released by the volcano subtly changed before, during and after the 2019 eruption.  https://t.co/pIvsX9vFiX',
#  '.@Stephenson_Data shares four steps that will help new data scientists deliver value quickly  https://t.co/j5aCUKPHa1',
#  '"Curricula is inherently brittle in a world where in-demand skills change this fast. A mentor can help you sort the signal from the noise — the hype from reality." @russ_poll explains how to actually find a mentor in data science  https://t.co/R0BakY1Hqw',
#  'Many common colour maps distort data through uneven colour gradients and are often unreadable to those with colour-vision deficiency. Thomas Bury shows how the scicomap package (scientific colour maps) can fix a large variety of colour maps  https://t.co/AiiCv4uf2c',
#  '@LinkLabsInc @IoTchannel Wow! Wonderful!! Congratulations and thank you. (And in my Maryland neighborhood too!)😎    —————  @IoTchannel @IoTCommunity #IoT #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing #Observability  https://t.co/2zrcINZCf3',
#  'Register now and build your #HPEDiscover 2021 Agenda today:  https://t.co/4UwG9tk2Cf by @HPE @HPE_Ezmeral @HPE_IoT @HPE_AI  ———— #Edge #Cloud #IoT #IIoT #IoTPL #IoTCommunity #AI #BigData #DataScience #MachineLearning #Industry40 #DigitalTransformation  https://t.co/TiOMVPgzsu',
#  'What is #ModelOps vs. #MLOps? “ModelOps is key to an organizations’ Enterprise #AI Strategy. It focuses on the operationalization of all AI and decision models.”  https://t.co/Fyfgpwbaux by @ModelOp_Co —————— #EnterpriseAI #MachineLearning #BigData #DataScience #ModelOpCo  https://t.co/usCH5IlYMg',
#  'Demystifying #AI with 10 top applications:  https://t.co/VXUy6wPcTv ———— #BigData #DataScience #DAIFE #DataMining #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #Algorithms #IoT #IIoT #IoTPL #IoTCommunity ——— Graphic source:  https://t.co/eGv1Htvlwu #abdsc  https://t.co/KmGkVOwVrj',
#  'Trends in #AI for next 5 years, including revenue, applications, and talent (#INFOGRAPHIC) ——————— #BigData #DataScience #MachineLearning #DeepLearning #ComputerVision #NLProc #DataLiteracy #AIStrategy #DigitalTransformation #EdgeAI #Edge #IoT #IIoT #IoTPL #IoTCommunity  https://t.co/mn7vFSgyyv',
#  '“1001 Free Things” You Can Do with Your Data — to Achieve Outcomes-as-a-Service:  https://t.co/oZx52nVoUL #DataMakesPossible ———— #BigData #DataScience #AI #MachineLearning #ComputerVision #NLProc #PredictiveAnalytics #PrescriptiveAnalytics #IoT #IIoT #IoTPL #AnomalyDetection',
#  '#MachineLearning for #Sensors —  https://t.co/hWKsYFYGNK  —————— #BigData #DataScience #IoT #IIoT #IoTPL #EdgeAnalytics #AI #DeepLearning #NeuralNetworks #EdgeComputing #GPU #TPU #CoreML #Industry40 #DigitalTwins #StreamingAnalytics #ComputerVision  https://t.co/6guepqCckg',
#  'Interesting #AI papers published in 2020:  https://t.co/5gy56Wx6BL —————— #abdsc #BigData #DataScience #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #NLProc #GANs #AutoML #Algorithms #DataScientists #IoTPL #IoT #IIoT #IoTCommunity #ObjectDetection  https://t.co/KeahJBil8z',
#  'Top Resources (Books &amp; Tutorials) To Learn #ComputerVision:  https://t.co/60hZ5dmZ1Y —————— #BigData #DataScience #DataMining #MachineLearning #AI #DeepLearning #Mathematics #NeuralNetworks #OpenCV #IoT #IIoT #IoTPL #IoTCommunity @IoTslam  ———— + See book:  https://t.co/FZ8KPrx2gK  https://t.co/xmXBqbIfNR',
#  '.@NVIDIA’s Neda Cvijetic explains the Science Behind Self-Driving Cars:  https://t.co/3rIYbB4DZK  ————— #AutonomousVehicles #AI #BigData #DataScience #MachineLearning #DeepLearning #ComputerVision @NVIDIAAI #IoT #IIoT #IoTPL #IoTCommunity #VR #AR #Industry40 #DigitalTwin  https://t.co/gY7rFjfHHp',
#  'My Keynote talk at Oracle #CodeOne: "#DataScience at the Intersection of #EmergingTechnologies" 👉 https://t.co/9jHZtBHLV4 ——— #BigData #AI #MachineLearning #IoT #IIoT #IoTPL #VR #AR #Industry40 #DigitalTwins #5G #Drones #UAV #ComputerVision #EmergingTech #4DPrinting #IoTCommunity  https://t.co/9Gg6g8HdJS',
#  'Biometric #IoT sensors shape the future of user interfaces:  https://t.co/csPzVDi36Z ————— #BigData #DataScience #AI #ComputerVision #MachineLearning #DeepLearning #NLU #EdgeComputing #IIoT #IoTPL #CX #UX #DigitalTransformation #IoTCommunity #Industry40 #LocationIntelligence  https://t.co/YgstVp7yBG',
#  '#ObjectDetection using #DeepLearning, for faster R-CNN (Region-based Convolutional #NeuralNetworks), YOLO (You Only Look Once), &amp; SSD Single-Shot Detector:  https://t.co/SL2ohOm8sZ —— #BigData #DataScience #AI #MachineLearning #ComputerVision #IoT #IIoT #IoTPL #IoTCommunity #abdsc  https://t.co/KbndBZQJsD',
#  'ApolloScape (world’s largest open-source dataset for #AutonomousDriving technology):  https://t.co/wPFkoUW3Gl ————— #BigData #DataScience #AI #IoT #IoTPL #IIoT #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #EdgeAI #abdsc  —— Research paper:  https://t.co/q304aC7AO4  https://t.co/IyMUyK1gaJ',
#  'Natural Language Trends in Visual Analysis:  https://t.co/3uGpOL7JXX On-Demand Webinar by @tableau and @DataScienceCtrl  ————— #abdsc #BigData #DataScience #DataDriven #DataLeadership #DataViz #BI #VisualAnalytics #DataStorytelling #AI #MachineLearning  https://t.co/GL5XvF25Ib',
#  '.@MasonMMcGough looks at pointer networks, a simple but versatile architecture that can be incorporated into neural networks for predicting sequences over variable-length input dictionaries  https://t.co/dxHGqqZmic',
#  '[On-demand] Data Streaming Success Stories with #ApacheKafka — How @Qlik &amp; @confluentinc Keep Your Data Fresh:  https://t.co/KvoGzrsG8H via @DataScienceCtrl ———— #abdsc #BigData #DataScience #AI #MachineLearning #StreamAnalytics #EdgeComputing #Edge #IoT #IIoT #IoTPL #IoTCommunity  https://t.co/I5ZzEFgDCs',
#  'Future of #AI in #UX Design:  https://t.co/htelHrN6Gb ————— #abdsc #CX #BigData #DataDriven #DataScience #MachineLearning #DesignThinking #DigitalTransformation  ———— 🌟🚀See this book… 👇👇👇',
#  'More Fun Math Problems for #MachineLearning Practitioners:  https://t.co/NTvxnzL4Z0 by @granvilleDSC via @DataScienceCtrl  ———— #abdsc #Mathematics #BigData #DataScience #AI #Statistics #Probability  https://t.co/oAGoUnidWu',
#  'Join elite #IoT Industry Leaders at the @IoTSlam Live 2021 event — learn how they are transforming their industries:  https://t.co/L3ehy4BJB5 ———— #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing @IoTCommunity  https://t.co/SBlrYWSLlF',
#  "Last week's top content for #DataScientists at @DataScienceCtrl &amp; @TechTarget 👉  https://t.co/ghgCV3Ub8j via @kurt_cagle —————— #BigData #DataScience #IoT #IoTCommunity #IIoT #IoTPL #AI #MachineLearning #ModelOps #XAI #DeepLearning #EdgeComputing #Python #DataLiteracy #CX #abdsc  https://t.co/SfVWKQs3dT",
#  '#ApacheSpark Basics in 7 10-minute tutorials:  https://t.co/dxohZUOBlW #abdsc #BigData #DataScience #AI #MachineLearning #IoT #IoTPL #IoTCommunity — 1)Install 2)RDD (Resilient Distributed Datasets) 3)DataFrames &amp; SQL 4)MLlib 5)Streaming 6)GraphX Graph Computation 7)GraphX &amp; #Neo4j  https://t.co/uzSinXNDSN',
#  'How #ApacheSpark and @Databricks Delta Lake unify your data:  https://t.co/NJMexaQqiE HT @DataScienceCtrl ————— #BigData #DataScience #AI #MachineLearning #DataStrategy #AnalyticsStrategy #DataLake #IoT #IIoT #IoTPL #StreamAnalytics #abdsc —— + See book:  https://t.co/Z34ovosl2X  https://t.co/kMDtl5C4aR',
#  '#MachineLearning Guide &amp; Tutorial for Developers and for ML Engineers:  https://t.co/hFM2Rg8oAa ——————— #abdsc #BigData #DataScience #DevOps #Algorithms #AI #DeepLearning #NeuralNetworks #DataScientists #IoT #IIoT #IoTPL #IoTCommunity  ———— +See this Book:  https://t.co/3xCIvUqAUV  https://t.co/K9sK8m8Gmx',
#  'The #Nvidia\xa0Jetson Nano is boosting the growing industrial #IoT revolution:  https://t.co/nblIzrxxmx ——— #abdsc #EdgeAnalytics #EdgeComputing #IIoT #IoTPL #IoTCommunity #StreamAnalytics #BigData #DataScience #AI #EdgeAI #MachineLearning #GPU —— See it here:  https://t.co/6fO6XRz55B  https://t.co/n1iJwiRywH',
#  'The #AI Business Transformation Playbook:  https://t.co/OlgfTxHEzF  "#IoT turns products into services" ————— #BigData #DataScience #MachineLearning #AIstrategy #DigitalTransformation #IIoT #IoTPL #IoTCommunity #Industry40 #abdsc ——— + See this book:  https://t.co/RLKdE0iQ4D  https://t.co/LNEsKCf1W6',
#  '#DataScience Use Cases… 🟠Marketing:  https://t.co/LJxw3cEsvf 🟢Sales:  https://t.co/Hul6PnFrwi —— #BigData #AI #MachineLearning #IoT #IoTPL #Adtech #Martech #RecSys #CMO #PredictiveAnalytics #ABtesting #abdsc  —— +Related Books:  https://t.co/etpRFRK4Nv and  https://t.co/33d8t52DlZ  https://t.co/WoPPL1J9J2',
#  'Resources for #Forecasting #PredictiveAnalytics and #PredictiveModeling:  https://t.co/UnKGGDGeoL ————— #BigData #MachineLearning #DataScience #Statistics #AI #IoT #IIoT #IoTPL #TimeSeries #StreamingAnalytics #Python #Rstats #abdsc —— + Some helpful books:  https://t.co/DNevpc4Uj6  https://t.co/T267pXhVei',
#  '#BigData in Engineering Applications:  https://t.co/tdsC0Mirw1  —————— #DataScience #AI #MachineLearning #DataEngineering #Industry40 #DigitalTransformation #IoT #IIoT #IoTPL #IoTCommunity #PredictiveAnalytics #EdgeComputing #abdsc  ——— + See the book here:  https://t.co/Vs0IFygEpb  https://t.co/8KGoq9ymG1',
#  'An Ultimate Guide to Matching and Propensity Score Matching by @leihua_ye  https://t.co/RePHK3VbXC',
#  'Disruption defines our world, and the latest health crisis is just the most recent example. Find out how to become more agile in an era of economic change. |  https://t.co/IPHFjkdwcY #scalingai #Dataiku #businesspreparedness #machinelearning #datascience  https://t.co/j9pY4r4BtD',
#  'The Science Table estimates for Delta spread continue to fluctuate, which is probably more a sign of low, noisy data than any change on the ground.  Delta (Orange) appears around flatish, to growing slightly.  Either way: A Delta R of ~1 is at least a potential threat.  https://t.co/oJD3NymYSN',
#  '.@SASsoftware advances the artificial intelligence of things (AIoT):  https://t.co/2RdFf5zc0T   #SASVisionary #SASGF #AI #Edge #EdgeAI #Industry40 #IoT #IIoT #IoTPL #IoTCommunity #BigData #Analytics #DataScience #MachineLearning #EdgeComputing #PredictiveAnalytics #IntelligentEdge  https://t.co/6TbagWbep8',
#  '“Based on responses, data science teams trend small (0-5 engineers), with light rigor on SDLC best practices (ex: version control); and most data scientists come from non-CS backgrounds, with minimal programming experience.”  https://t.co/zuMec220LE',
#  'Parallel Computing On Raspberry Pi 4B+ IoT Boards Made Easier by @RatzArthur   https://t.co/Nwydqi80qe',
#  'Maybe I\'m behind on this! The Gartner Hype Cycle for Data Science and Machine Learning has listed Synthetic Data as "On the Rise" for the last two years  https://t.co/GbQ8NsRSbT',
#  'Todays AI and Machine Learning News:  https://t.co/WYtjGXLRIw Thanks to @CorkDigital @kashyapsandeep @isunnyrana #ai #datascience',
#  'Watch ON-DEMAND the #EDA (#EventDriven Architecture) Summit:  https://t.co/MWHgvd9yEo by  @EDAsummit @solacedotcom  #EDASummit #BigData #DataScience #AI #EdgeComputing #MachineLearning #IoT #IIoT #IoTPL #IoTCommunity #ERP #Logistics #Industry40 #DigitalTransformation  including…  https://t.co/w0kRFPO7aV',
#  '"I think problem formulation is even more important than either data or models."  @reddup argues that data scientists should consider business goal-framing a core, crucial skill.  https://t.co/OUxlPj7xzr',
#  'Todays Digital Transformation, Data,  Innovation &amp; Analytics News:  https://t.co/wkDC8gr6Eo Thanks to @nyike @AWP_Art @FmFrancoise #ai #datascience',
#  'Just getting started on your data and analytics journey? Fully managed and hosted by us, Dataiku Online allows for easy and agile setup, streamlining the path to actionable insights. |  https://t.co/TzOfegfMEt #DataScience #EnterpriseAI #MachineLearning',
#  'Bring all of your #data to your favorite #BI or data science #datasci tool: @SnowflakeDB @awscloud #Redshift #Google #BigQuery @Azure_Synapse @oracle @Teradata and more data warehouses and destinations that seamlessly integrate with Datameer Spectrum ➡️    https://t.co/ljZElc1iWf',
#  '“If only a small fraction of your people use SQL as good as they use Excel, the entire organization would benefit immensely.” - Sergey Fogelson, VP of Data Science and Modeling at @ViacomCBS.   Give his @DataCamp podcast episode a listen.  #DataScience #SQL #DataEngineering',
#  'Anecdotally, I’m seeing more pro-vaccine (low risk) people wondering if it was worth “trusting the science” while data is still emerging on vaccines when 🇨🇦 isn’t changing policy in line with vaccine uptake. This is a potentially big problem.',
#  '@AP_Skill has Associated with @nasscomfs @nasscom Initiative supported by @github LAUNCHING ONLINE FREE @Microsoft AI Classroom Series to deliver Microsoft’s #ArtificialInteligence #MachineLearning and #DataScience expertise to Students, Faculty and Researchers.  https://t.co/4augiIghIa',
#  'My latest article: "Best practices to build #DataLiteracy into your Gen Z workforce" — I hope you enjoy reading it:  https://t.co/88CkYFEX63 via @ExasolAG ——— #DataFluency #DataLeadership #BeDataBrilliant #DigitalTransformation #BigData #Analytics #DataScience #AI #MachineLearning  https://t.co/J5rL4eHlUa',
#  'Christopher Graves explains the impact of behavioral science on marketing, the challenges of winning the trust of consumers, and advises brands to use data wisely.    https://t.co/Bkp5Lj4P8A',
#  "Don't miss this discussion of the upcoming LCRD launch tomorrow at the @ascendspace Summit!  We will be highlighting the profound benefits of @NASALaserComm @NASA_Technology — namely higher data rates for exploration and science missions!",
#  'In this Python deep dive from Alan Davies, we learn how to use Python Flask and Ajax to facilitate information passing between server and client.  https://t.co/xcf8tSM0Yh',
#  'I have 2 online #DataScience #MachineLearning Modeling Courses. Look here: DS 101:  https://t.co/wUQaGf1JbB DS 102:  https://t.co/3FwcYLAF9q ———— #BigData #AI #DataScientists #PredictiveModeling #Algorithms #DataLiteracy #DataLeadership #PredictiveAnalytics #IoT #IIoT #IoTPL #ODSC  https://t.co/wrErPsjLp7',
#  'The latest Data2Decisions (#BigData Analytics)!  https://t.co/BuntI7YDxp #datascience #bigdata',
#  "Data science meets astronomy in Madhumita Dange's project, which uses CNNs and U-Net to construct undistorted images of distant galaxies.  https://t.co/veZOzi3Bik",
#  '(9/n) By empowering and equipping Black women in quantitative sciences, @sadiecollective addresses the pipeline and pathway problem in economics, finance, data science, and public policy through curated content creation, programming, and mentorship.   https://t.co/THo47GzXAz',
#  '#FICO honors black Americans who made a significant impact in the field of #DataScience.  https://t.co/ImCTpyXTFp',
#  '"The modern data stack is messy and complicated"—so @prukalpa put together a very useful beginner\'s guide (with books, podcasts, blogs, and more) to help new teammates stay on top of data science news and trends.  https://t.co/P6NCuNnqDT',
#  '"Failure to consider reproducibility beforehand could sequel several repercussions further in development." @kpwritescode zooms in on the importance of reproducible machine learning pipelines.  https://t.co/dTXr03BV2F',
#  'Linear regression and logistic regression are the two most widely used statistical models and act like master keys, unlocking the secrets hidden in datasets. Learn all about these methods in our course.  https://t.co/Vhs0kG4Zib #python #datascience  https://t.co/YwiCSScqy2',
#  '"The main developers and deployers of AI are focused on profit-seeking and social control [...]."  When @pewresearch asked 602 tech leaders, researchers, and activists about the prospects of #AIEthics, the responses they were mostly pessimistic. #TDSPick  https://t.co/04hqW7xrQ2',
#  'Discover how Dataiku can drastically reduce total cost of ownership for data science initiatives and help your organization become a more intelligent enterprise. |  https://t.co/v3v9mAtUWS #DataScience #EnterpriseAI #TCO',
#  'Did you ever get stuck trying to have your conda environment show up in Jupyter Notebooks? @benbogart proposes three methods to get it done.  https://t.co/U0SoMPEX2Y',
#  'Your weekend must-reads are here—including @pandeyparul on automating the structure of your projects, @prukalpa on implementing a brand-new data warehouse, and @mgsosna on the surprising similarities between algorithms and schools of fish.  https://t.co/Cu9GF9pEhL',
#  "📅 Data-focused role with @NationalTheatre is closing soon 📅  As Head of Data &amp; Insight you'll combine strategic thinking with hands-on implementation, with aspects of data science, project management, IT development &amp; leading a team. Ends 21/06  ➡️ https://t.co/ilZnruKm8Y",
#  'We need to stop confusing statistical significance with scientific significance, says @ericjdaza in his post on the language we use around statistics—and how it frames value, truth, and decision-making.  https://t.co/ErXXpN5h2k',
#  'But whatever happens we should all admit that data loggers are never actually going to be used by the majority of science teachers ;)',
#  '"The main developers and deployers of AI are focused on profit-seeking and social control [...]."   @pewresearch asked 602 tech leaders, researchers, and activists about the prospects of #AIEthics. The responses were largely pessimistic. #TDSPick  https://t.co/04hqW7xrQ2',
#  'Are you new to your data science or analytics role? Here are some principles and strategies  to create a scheduled query based on your specific scenario, courtesy of Astandri Koesriputranto.  https://t.co/OTliNhqXxq',
#  'CBSE has collaborated with which tech giant to introduce Coding and Data Science as new subjects in the 2021-22 academic session?  A. IBM B. Google C. Microsoft D. TCS  Reply Answer 📝  Please ❤️ &amp; Retweet 🔃  #currentaffairs #mcq #gk #generalawareness #bestcurrentaffairs',
#  'In his latest project, @brain_robber leveraged time series forecasting to predict solar irradiation—which has potential to help solar-energy generation become more efficient.  https://t.co/48WxeAqSfk',
#  "America's #COVID19 evidence-based response, leadership that respects data, scientists, and funds science have led a turnaround in the country. India needs a course correction too, @iimb_official writes  https://t.co/k5y9Yr3mN1",
#  "You can't prepare for every single coding interview question, but possessing a solid, versatile approach for tackling them could be immensely helpful. Here's how @_aqeelanwar recommends you prepare for your next round.  https://t.co/r1DnSPRNY1",
#  'Amid a pandemic-induced global digital transformation drive, TCS, Infosys and Wipro train are training client workforces in app development, data science, artificial intelligence, &amp; industrial IoT, report @Alnoor_ET &amp; @Anandi_ET   https://t.co/3BrdiCaada',
#  '#Data has shown that the Whakaari volcano had released certain telltale gases before erupting. Using high-resolution #satellite data and #computer algorithms, #scientists can improve volcano monitoring. #science #earth    https://t.co/vbRGXPP5G3',
#  "Ontario's COVID-19 Science Advisory Table says they need more data on how Step 1 of reopening has impacted the province before moving on.   https://t.co/q0zFqFTiy4",
#  'Looking for a statistics refresher? Join Luís Roque in the latest from his weekly series—in this post, he covers sampling distributions with Python.  https://t.co/h0cX3qtuHB',
#  'When and how should you move from Pandas to Spark? @sanket107 explains what it takes to make an informed decision.  https://t.co/3GLv7KLDtL',
#  'A volcano that spewed fire last month in Congo has since settled down, but a new flashpoint has erupted at the geophysical observatory that monitors it, with accusations that “neocolonial” partners in Europe deprived them of key data.  https://t.co/KqqTwDwhbt',
#  'Excellent interview. Data. Science. Facts!',
#  '@HeroineRipley Yes, I do, it happened before the clinical trial data was out, while Trump was pushing a dangerous unproven medication and leaning on the FDA to make unjustified approvals.  Then the data came out, was reviewed, and Dems went with the science—while the GOP pushed misinformation.',
#  'Sheriff Knezovich: Stop Using "Junk Science" to bash/devalue law enforcement.  #Sheriff -“Junk Science” math used to try &amp; prove false narrative-why Facts/Real Science should be used when comparing #police shootings &amp; other #LawEnforcement data.  https://t.co/kwDB5oUBSZ   #Spokane  https://t.co/4so3MWKduC',
#  'Join @IoTCommunity at the @IoTSlam Live 2021 event, June 24 in New Orleans, to validate &amp; enhance your #IoT, #Edge, #AI, and #5G strategies:  https://t.co/L3ehy4TkZF  ————— #IoTPL #IIoT #IoTCommunity #EdgeAI #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing  https://t.co/7SDddU3w3N',
#  'White men who had Black neighbors early in life were more likely to be registered Democrats more than 70 years later, according to an analysis of linked administrative data. The findings were consistent across regions of the U.S. @ScienceAdvances  https://t.co/1cZsTgbHth  https://t.co/YJ8GCiBMra',
#  '@clairernak @shkempticismr @MonsieurCS @DLaVa84 @RobertHarding Thanks for the retweets and good luck with your careers in journalism and data science!',
#  "With machine learning pipelines becoming increasingly complex (if not downright clunky), @andrejusb wanted to implement a streamlined end-to-end solution. Here's what he came up with.  https://t.co/TpLe5RPjRo",
#  'Since #datascience is only as useful as the systems it powers, everyone in the #tech ecosystem needs to think like a data scientist to get maximum mileage from their data science engagement. Here are three questions to help hone your data science thinking.  https://t.co/tt5xWaSrmS',
#  '[From the archives:] “The most surprising result was really seeing how connected the data was," said Benjamin Squire, Senior Data Scientist at @MeredithCorp     https://t.co/nLXJzVvl4t #DataScience #GraphDatabases',
#  "Jupyter Notebooks are everywhere, which might explain why they sometimes get a bad rep among data scientists. @MaartenGr comes in the service's defense, highlighting its benefits—and showing ways you can supercharge it to improve your workflows.  https://t.co/Bx1cK9bPPX",
#  "If you're view of #1A extends only to your view, no thanks.  I believe in the marketplace of ideas.  Good science and good data make for good decisions.  Human resources are our most important resource.  This aint complicated.",
#  'At @AeroFarms, #horticulture intersects with #genetics, #foodsafety, #datascience, and #nutrition, giving us the distinct capability to understand #plantbiology &amp; harvest the best tasting greens with fewer resources. Shop our greens  https://t.co/ORLD20lztY.  #VerticalFarming #NJ  https://t.co/H2VgThZx31',
#  'The line separating data scientists from data engineers is hazy and shifts from one company to another. @snr14 argues that to find success as a data scientist, you "should possess the ability and skills to handle some data engineering tasks."  https://t.co/AaFGejpxUy',
#  "I'm not even talking about his vaccine decision, but that tweet. As for the former...the way I see it...  1. Choosing to get vaccinated or not is your personal choice.  2. But you can't get mad when that choice impacts you based on decisions others have made around science/data.",
#  'Many data scientists say networking is key for finding a great job, but... how does one actually network? What does it entail, and what things should you stay mindful of? Isabelle Flückiger lays it all out in a detailed, step-by-step guide.  https://t.co/zYFpk4Wt9o',
#  'yet more data,science on how Ivermectin works. main thing is it takes up the Ace 2 parking spot where covid likes to park, thus inhibits binding.  https://t.co/t4H5LQn01U',
#  'A polyglot scientist tries Topcoder and becomes development champion multiple times, data science copilot and MVP. Learn more about birdofpreyru by joining us:  https://t.co/GTtQ4PJmJf #Topcoder #Topcodernation #AMA  https://t.co/SrMeuoN3nE',
#  'Learn how #datascience has become an important part of #business with this free #openSAP #MOOC  https://t.co/PsrmFNPLlU  https://t.co/RYGCP528Sc']

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")

for t in tweets_filtered:
  print(t, "\n", classifier(t), "\n\n\n")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# "We need a paradigm shift from model-centric to data-centric ML development." Tobias Schaffrath Rosario shares the reasons why so many applied ML projects fail and proposes a solution  https://t.co/nf2y1HQ1NH
#  [{'label': 'NEGATIVE', 'score': 0.9962561130523682}]
#
#
#
# Using high-resolution satellite data and computer algorithms, scientists have revealed how gases released by the volcano subtly changed before, during and after the 2019 eruption.  https://t.co/pIvsX9vFiX
#  [{'label': 'POSITIVE', 'score': 0.7162714600563049}]
#
#
#
# .@Stephenson_Data shares four steps that will help new data scientists deliver value quickly  https://t.co/j5aCUKPHa1
#  [{'label': 'POSITIVE', 'score': 0.997282862663269}]
#
#
#
# "Curricula is inherently brittle in a world where in-demand skills change this fast. A mentor can help you sort the signal from the noise — the hype from reality." @russ_poll explains how to actually find a mentor in data science  https://t.co/R0BakY1Hqw
#  [{'label': 'NEGATIVE', 'score': 0.9853827953338623}]
#
#
#
# Many common colour maps distort data through uneven colour gradients and are often unreadable to those with colour-vision deficiency. Thomas Bury shows how the scicomap package (scientific colour maps) can fix a large variety of colour maps  https://t.co/AiiCv4uf2c
#  [{'label': 'NEGATIVE', 'score': 0.9969993829727173}]
#
#
#
# @LinkLabsInc @IoTchannel Wow! Wonderful!! Congratulations and thank you. (And in my Maryland neighborhood too!)😎    —————  @IoTchannel @IoTCommunity #IoT #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing #Observability  https://t.co/2zrcINZCf3
#  [{'label': 'POSITIVE', 'score': 0.998377799987793}]
#
#
#
# Register now and build your #HPEDiscover 2021 Agenda today:  https://t.co/4UwG9tk2Cf by @HPE @HPE_Ezmeral @HPE_IoT @HPE_AI  ———— #Edge #Cloud #IoT #IIoT #IoTPL #IoTCommunity #AI #BigData #DataScience #MachineLearning #Industry40 #DigitalTransformation  https://t.co/TiOMVPgzsu
#  [{'label': 'NEGATIVE', 'score': 0.9937596917152405}]
#
#
#
# What is #ModelOps vs. #MLOps? “ModelOps is key to an organizations’ Enterprise #AI Strategy. It focuses on the operationalization of all AI and decision models.”  https://t.co/Fyfgpwbaux by @ModelOp_Co —————— #EnterpriseAI #MachineLearning #BigData #DataScience #ModelOpCo  https://t.co/usCH5IlYMg
#  [{'label': 'NEGATIVE', 'score': 0.9002626538276672}]
#
#
#
# Demystifying #AI with 10 top applications:  https://t.co/VXUy6wPcTv ———— #BigData #DataScience #DAIFE #DataMining #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #Algorithms #IoT #IIoT #IoTPL #IoTCommunity ——— Graphic source:  https://t.co/eGv1Htvlwu #abdsc  https://t.co/KmGkVOwVrj
#  [{'label': 'NEGATIVE', 'score': 0.9883890151977539}]
#
#
#
# Trends in #AI for next 5 years, including revenue, applications, and talent (#INFOGRAPHIC) ——————— #BigData #DataScience #MachineLearning #DeepLearning #ComputerVision #NLProc #DataLiteracy #AIStrategy #DigitalTransformation #EdgeAI #Edge #IoT #IIoT #IoTPL #IoTCommunity  https://t.co/mn7vFSgyyv
#  [{'label': 'NEGATIVE', 'score': 0.9868148565292358}]
#
#
#
# “1001 Free Things” You Can Do with Your Data — to Achieve Outcomes-as-a-Service:  https://t.co/oZx52nVoUL #DataMakesPossible ———— #BigData #DataScience #AI #MachineLearning #ComputerVision #NLProc #PredictiveAnalytics #PrescriptiveAnalytics #IoT #IIoT #IoTPL #AnomalyDetection
#  [{'label': 'NEGATIVE', 'score': 0.9846342206001282}]
#
#
#
# #MachineLearning for #Sensors —  https://t.co/hWKsYFYGNK  —————— #BigData #DataScience #IoT #IIoT #IoTPL #EdgeAnalytics #AI #DeepLearning #NeuralNetworks #EdgeComputing #GPU #TPU #CoreML #Industry40 #DigitalTwins #StreamingAnalytics #ComputerVision  https://t.co/6guepqCckg
#  [{'label': 'NEGATIVE', 'score': 0.9930354952812195}]
#
#
#
# Interesting #AI papers published in 2020:  https://t.co/5gy56Wx6BL —————— #abdsc #BigData #DataScience #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #NLProc #GANs #AutoML #Algorithms #DataScientists #IoTPL #IoT #IIoT #IoTCommunity #ObjectDetection  https://t.co/KeahJBil8z
#  [{'label': 'NEGATIVE', 'score': 0.9513992667198181}]
#
#
#
# Top Resources (Books &amp; Tutorials) To Learn #ComputerVision:  https://t.co/60hZ5dmZ1Y —————— #BigData #DataScience #DataMining #MachineLearning #AI #DeepLearning #Mathematics #NeuralNetworks #OpenCV #IoT #IIoT #IoTPL #IoTCommunity @IoTslam  ———— + See book:  https://t.co/FZ8KPrx2gK  https://t.co/xmXBqbIfNR
#  [{'label': 'NEGATIVE', 'score': 0.9782540798187256}]
#
#
#
# .@NVIDIA’s Neda Cvijetic explains the Science Behind Self-Driving Cars:  https://t.co/3rIYbB4DZK  ————— #AutonomousVehicles #AI #BigData #DataScience #MachineLearning #DeepLearning #ComputerVision @NVIDIAAI #IoT #IIoT #IoTPL #IoTCommunity #VR #AR #Industry40 #DigitalTwin  https://t.co/gY7rFjfHHp
#  [{'label': 'NEGATIVE', 'score': 0.989087700843811}]
#
#
#
# My Keynote talk at Oracle #CodeOne: "#DataScience at the Intersection of #EmergingTechnologies" 👉 https://t.co/9jHZtBHLV4 ——— #BigData #AI #MachineLearning #IoT #IIoT #IoTPL #VR #AR #Industry40 #DigitalTwins #5G #Drones #UAV #ComputerVision #EmergingTech #4DPrinting #IoTCommunity  https://t.co/9Gg6g8HdJS
#  [{'label': 'NEGATIVE', 'score': 0.9912173748016357}]
#
#
#
# Biometric #IoT sensors shape the future of user interfaces:  https://t.co/csPzVDi36Z ————— #BigData #DataScience #AI #ComputerVision #MachineLearning #DeepLearning #NLU #EdgeComputing #IIoT #IoTPL #CX #UX #DigitalTransformation #IoTCommunity #Industry40 #LocationIntelligence  https://t.co/YgstVp7yBG
#  [{'label': 'NEGATIVE', 'score': 0.974635660648346}]
#
#
#
# #ObjectDetection using #DeepLearning, for faster R-CNN (Region-based Convolutional #NeuralNetworks), YOLO (You Only Look Once), &amp; SSD Single-Shot Detector:  https://t.co/SL2ohOm8sZ —— #BigData #DataScience #AI #MachineLearning #ComputerVision #IoT #IIoT #IoTPL #IoTCommunity #abdsc  https://t.co/KbndBZQJsD
#  [{'label': 'NEGATIVE', 'score': 0.9970974922180176}]
#
#
#
# ApolloScape (world’s largest open-source dataset for #AutonomousDriving technology):  https://t.co/wPFkoUW3Gl ————— #BigData #DataScience #AI #IoT #IoTPL #IIoT #MachineLearning #DeepLearning #NeuralNetworks #ComputerVision #EdgeAI #abdsc  —— Research paper:  https://t.co/q304aC7AO4  https://t.co/IyMUyK1gaJ
#  [{'label': 'NEGATIVE', 'score': 0.986710250377655}]
#
#
#
# Natural Language Trends in Visual Analysis:  https://t.co/3uGpOL7JXX On-Demand Webinar by @tableau and @DataScienceCtrl  ————— #abdsc #BigData #DataScience #DataDriven #DataLeadership #DataViz #BI #VisualAnalytics #DataStorytelling #AI #MachineLearning  https://t.co/GL5XvF25Ib
#  [{'label': 'NEGATIVE', 'score': 0.9933897256851196}]
#
#
#
# .@MasonMMcGough looks at pointer networks, a simple but versatile architecture that can be incorporated into neural networks for predicting sequences over variable-length input dictionaries  https://t.co/dxHGqqZmic
#  [{'label': 'POSITIVE', 'score': 0.9905285239219666}]
#
#
#
# [On-demand] Data Streaming Success Stories with #ApacheKafka — How @Qlik &amp; @confluentinc Keep Your Data Fresh:  https://t.co/KvoGzrsG8H via @DataScienceCtrl ———— #abdsc #BigData #DataScience #AI #MachineLearning #StreamAnalytics #EdgeComputing #Edge #IoT #IIoT #IoTPL #IoTCommunity  https://t.co/I5ZzEFgDCs
#  [{'label': 'POSITIVE', 'score': 0.9926238059997559}]
#
#
#
# Future of #AI in #UX Design:  https://t.co/htelHrN6Gb ————— #abdsc #CX #BigData #DataDriven #DataScience #MachineLearning #DesignThinking #DigitalTransformation  ———— 🌟🚀See this book… 👇👇👇
#  [{'label': 'NEGATIVE', 'score': 0.9899098873138428}]
#
#
#
# More Fun Math Problems for #MachineLearning Practitioners:  https://t.co/NTvxnzL4Z0 by @granvilleDSC via @DataScienceCtrl  ———— #abdsc #Mathematics #BigData #DataScience #AI #Statistics #Probability  https://t.co/oAGoUnidWu
#  [{'label': 'NEGATIVE', 'score': 0.9844600558280945}]
#
#
#
# Join elite #IoT Industry Leaders at the @IoTSlam Live 2021 event — learn how they are transforming their industries:  https://t.co/L3ehy4BJB5 ———— #IoTPL #IIoT #IoTCommunity #AI #Edge #EdgeAI #5G #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing @IoTCommunity  https://t.co/SBlrYWSLlF
#  [{'label': 'POSITIVE', 'score': 0.9275559186935425}]
#
#
#
# Last week's top content for #DataScientists at @DataScienceCtrl &amp; @TechTarget 👉  https://t.co/ghgCV3Ub8j via @kurt_cagle —————— #BigData #DataScience #IoT #IoTCommunity #IIoT #IoTPL #AI #MachineLearning #ModelOps #XAI #DeepLearning #EdgeComputing #Python #DataLiteracy #CX #abdsc  https://t.co/SfVWKQs3dT
#  [{'label': 'NEGATIVE', 'score': 0.9928666353225708}]
#
#
#
# #ApacheSpark Basics in 7 10-minute tutorials:  https://t.co/dxohZUOBlW #abdsc #BigData #DataScience #AI #MachineLearning #IoT #IoTPL #IoTCommunity — 1)Install 2)RDD (Resilient Distributed Datasets) 3)DataFrames &amp; SQL 4)MLlib 5)Streaming 6)GraphX Graph Computation 7)GraphX &amp; #Neo4j  https://t.co/uzSinXNDSN
#  [{'label': 'NEGATIVE', 'score': 0.9948242902755737}]
#
#
#
# How #ApacheSpark and @Databricks Delta Lake unify your data:  https://t.co/NJMexaQqiE HT @DataScienceCtrl ————— #BigData #DataScience #AI #MachineLearning #DataStrategy #AnalyticsStrategy #DataLake #IoT #IIoT #IoTPL #StreamAnalytics #abdsc —— + See book:  https://t.co/Z34ovosl2X  https://t.co/kMDtl5C4aR
#  [{'label': 'NEGATIVE', 'score': 0.9963002800941467}]
#
#
#
# #MachineLearning Guide &amp; Tutorial for Developers and for ML Engineers:  https://t.co/hFM2Rg8oAa ——————— #abdsc #BigData #DataScience #DevOps #Algorithms #AI #DeepLearning #NeuralNetworks #DataScientists #IoT #IIoT #IoTPL #IoTCommunity  ———— +See this Book:  https://t.co/3xCIvUqAUV  https://t.co/K9sK8m8Gmx
#  [{'label': 'NEGATIVE', 'score': 0.9946331977844238}]
#
#
#
# The #Nvidia Jetson Nano is boosting the growing industrial #IoT revolution:  https://t.co/nblIzrxxmx ——— #abdsc #EdgeAnalytics #EdgeComputing #IIoT #IoTPL #IoTCommunity #StreamAnalytics #BigData #DataScience #AI #EdgeAI #MachineLearning #GPU —— See it here:  https://t.co/6fO6XRz55B  https://t.co/n1iJwiRywH
#  [{'label': 'POSITIVE', 'score': 0.9902964234352112}]
#
#
#
# The #AI Business Transformation Playbook:  https://t.co/OlgfTxHEzF  "#IoT turns products into services" ————— #BigData #DataScience #MachineLearning #AIstrategy #DigitalTransformation #IIoT #IoTPL #IoTCommunity #Industry40 #abdsc ——— + See this book:  https://t.co/RLKdE0iQ4D  https://t.co/LNEsKCf1W6
#  [{'label': 'NEGATIVE', 'score': 0.9943228960037231}]
#
#
#
# #DataScience Use Cases… 🟠Marketing:  https://t.co/LJxw3cEsvf 🟢Sales:  https://t.co/Hul6PnFrwi —— #BigData #AI #MachineLearning #IoT #IoTPL #Adtech #Martech #RecSys #CMO #PredictiveAnalytics #ABtesting #abdsc  —— +Related Books:  https://t.co/etpRFRK4Nv and  https://t.co/33d8t52DlZ  https://t.co/WoPPL1J9J2
#  [{'label': 'NEGATIVE', 'score': 0.9954877495765686}]
#
#
#
# Resources for #Forecasting #PredictiveAnalytics and #PredictiveModeling:  https://t.co/UnKGGDGeoL ————— #BigData #MachineLearning #DataScience #Statistics #AI #IoT #IIoT #IoTPL #TimeSeries #StreamingAnalytics #Python #Rstats #abdsc —— + Some helpful books:  https://t.co/DNevpc4Uj6  https://t.co/T267pXhVei
#  [{'label': 'NEGATIVE', 'score': 0.9926952123641968}]
#
#
#
# #BigData in Engineering Applications:  https://t.co/tdsC0Mirw1  —————— #DataScience #AI #MachineLearning #DataEngineering #Industry40 #DigitalTransformation #IoT #IIoT #IoTPL #IoTCommunity #PredictiveAnalytics #EdgeComputing #abdsc  ——— + See the book here:  https://t.co/Vs0IFygEpb  https://t.co/8KGoq9ymG1
#  [{'label': 'NEGATIVE', 'score': 0.9937357306480408}]
#
#
#
# An Ultimate Guide to Matching and Propensity Score Matching by @leihua_ye  https://t.co/RePHK3VbXC
#  [{'label': 'POSITIVE', 'score': 0.9840436577796936}]
#
#
#
# Disruption defines our world, and the latest health crisis is just the most recent example. Find out how to become more agile in an era of economic change. |  https://t.co/IPHFjkdwcY #scalingai #Dataiku #businesspreparedness #machinelearning #datascience  https://t.co/j9pY4r4BtD
#  [{'label': 'NEGATIVE', 'score': 0.7773150205612183}]
#
#
#
# The Science Table estimates for Delta spread continue to fluctuate, which is probably more a sign of low, noisy data than any change on the ground.  Delta (Orange) appears around flatish, to growing slightly.  Either way: A Delta R of ~1 is at least a potential threat.  https://t.co/oJD3NymYSN
#  [{'label': 'NEGATIVE', 'score': 0.9995710253715515}]
#
#
#
# .@SASsoftware advances the artificial intelligence of things (AIoT):  https://t.co/2RdFf5zc0T   #SASVisionary #SASGF #AI #Edge #EdgeAI #Industry40 #IoT #IIoT #IoTPL #IoTCommunity #BigData #Analytics #DataScience #MachineLearning #EdgeComputing #PredictiveAnalytics #IntelligentEdge  https://t.co/6TbagWbep8
#  [{'label': 'NEGATIVE', 'score': 0.9786344766616821}]
#
#
#
# “Based on responses, data science teams trend small (0-5 engineers), with light rigor on SDLC best practices (ex: version control); and most data scientists come from non-CS backgrounds, with minimal programming experience.”  https://t.co/zuMec220LE
#  [{'label': 'NEGATIVE', 'score': 0.9926798343658447}]
#
#
#
# Parallel Computing On Raspberry Pi 4B+ IoT Boards Made Easier by @RatzArthur   https://t.co/Nwydqi80qe
#  [{'label': 'NEGATIVE', 'score': 0.9966866374015808}]
#
#
#
# Maybe I'm behind on this! The Gartner Hype Cycle for Data Science and Machine Learning has listed Synthetic Data as "On the Rise" for the last two years  https://t.co/GbQ8NsRSbT
#  [{'label': 'POSITIVE', 'score': 0.6227826476097107}]
#
#
#
# Todays AI and Machine Learning News:  https://t.co/WYtjGXLRIw Thanks to @CorkDigital @kashyapsandeep @isunnyrana #ai #datascience
#  [{'label': 'POSITIVE', 'score': 0.8079670667648315}]
#
#
#
# Watch ON-DEMAND the #EDA (#EventDriven Architecture) Summit:  https://t.co/MWHgvd9yEo by  @EDAsummit @solacedotcom  #EDASummit #BigData #DataScience #AI #EdgeComputing #MachineLearning #IoT #IIoT #IoTPL #IoTCommunity #ERP #Logistics #Industry40 #DigitalTransformation  including…  https://t.co/w0kRFPO7aV
#  [{'label': 'NEGATIVE', 'score': 0.9927995204925537}]
#
#
#
# "I think problem formulation is even more important than either data or models."  @reddup argues that data scientists should consider business goal-framing a core, crucial skill.  https://t.co/OUxlPj7xzr
#  [{'label': 'NEGATIVE', 'score': 0.9630304574966431}]
#
#
#
# Todays Digital Transformation, Data,  Innovation &amp; Analytics News:  https://t.co/wkDC8gr6Eo Thanks to @nyike @AWP_Art @FmFrancoise #ai #datascience
#  [{'label': 'POSITIVE', 'score': 0.986786425113678}]
#
#
#
# Just getting started on your data and analytics journey? Fully managed and hosted by us, Dataiku Online allows for easy and agile setup, streamlining the path to actionable insights. |  https://t.co/TzOfegfMEt #DataScience #EnterpriseAI #MachineLearning
#  [{'label': 'POSITIVE', 'score': 0.9265982508659363}]
#
#
#
# Bring all of your #data to your favorite #BI or data science #datasci tool: @SnowflakeDB @awscloud #Redshift #Google #BigQuery @Azure_Synapse @oracle @Teradata and more data warehouses and destinations that seamlessly integrate with Datameer Spectrum ➡️    https://t.co/ljZElc1iWf
#  [{'label': 'POSITIVE', 'score': 0.7481381893157959}]
#
#
#
# “If only a small fraction of your people use SQL as good as they use Excel, the entire organization would benefit immensely.” - Sergey Fogelson, VP of Data Science and Modeling at @ViacomCBS.   Give his @DataCamp podcast episode a listen.  #DataScience #SQL #DataEngineering
#  [{'label': 'POSITIVE', 'score': 0.9944350719451904}]
#
#
#
# Anecdotally, I’m seeing more pro-vaccine (low risk) people wondering if it was worth “trusting the science” while data is still emerging on vaccines when 🇨🇦 isn’t changing policy in line with vaccine uptake. This is a potentially big problem.
#  [{'label': 'NEGATIVE', 'score': 0.9975661039352417}]
#
#
#
# @AP_Skill has Associated with @nasscomfs @nasscom Initiative supported by @github LAUNCHING ONLINE FREE @Microsoft AI Classroom Series to deliver Microsoft’s #ArtificialInteligence #MachineLearning and #DataScience expertise to Students, Faculty and Researchers.  https://t.co/4augiIghIa
#  [{'label': 'NEGATIVE', 'score': 0.9766649007797241}]
#
#
#
# My latest article: "Best practices to build #DataLiteracy into your Gen Z workforce" — I hope you enjoy reading it:  https://t.co/88CkYFEX63 via @ExasolAG ——— #DataFluency #DataLeadership #BeDataBrilliant #DigitalTransformation #BigData #Analytics #DataScience #AI #MachineLearning  https://t.co/J5rL4eHlUa
#  [{'label': 'NEGATIVE', 'score': 0.9424686431884766}]
#
#
#
# Christopher Graves explains the impact of behavioral science on marketing, the challenges of winning the trust of consumers, and advises brands to use data wisely.    https://t.co/Bkp5Lj4P8A
#  [{'label': 'POSITIVE', 'score': 0.9908248782157898}]
#
#
#
# Don't miss this discussion of the upcoming LCRD launch tomorrow at the @ascendspace Summit!  We will be highlighting the profound benefits of @NASALaserComm @NASA_Technology — namely higher data rates for exploration and science missions!
#  [{'label': 'POSITIVE', 'score': 0.9991968274116516}]
#
#
#
# In this Python deep dive from Alan Davies, we learn how to use Python Flask and Ajax to facilitate information passing between server and client.  https://t.co/xcf8tSM0Yh
#  [{'label': 'NEGATIVE', 'score': 0.6254047751426697}]
#
#
#
# I have 2 online #DataScience #MachineLearning Modeling Courses. Look here: DS 101:  https://t.co/wUQaGf1JbB DS 102:  https://t.co/3FwcYLAF9q ———— #BigData #AI #DataScientists #PredictiveModeling #Algorithms #DataLiteracy #DataLeadership #PredictiveAnalytics #IoT #IIoT #IoTPL #ODSC  https://t.co/wrErPsjLp7
#  [{'label': 'NEGATIVE', 'score': 0.9959064722061157}]
#
#
#
# The latest Data2Decisions (#BigData Analytics)!  https://t.co/BuntI7YDxp #datascience #bigdata
#  [{'label': 'NEGATIVE', 'score': 0.9935504198074341}]
#
#
#
# Data science meets astronomy in Madhumita Dange's project, which uses CNNs and U-Net to construct undistorted images of distant galaxies.  https://t.co/veZOzi3Bik
#  [{'label': 'POSITIVE', 'score': 0.9800295233726501}]
#
#
#
# (9/n) By empowering and equipping Black women in quantitative sciences, @sadiecollective addresses the pipeline and pathway problem in economics, finance, data science, and public policy through curated content creation, programming, and mentorship.   https://t.co/THo47GzXAz
#  [{'label': 'POSITIVE', 'score': 0.9935709238052368}]
#
#
#
# #FICO honors black Americans who made a significant impact in the field of #DataScience.  https://t.co/ImCTpyXTFp
#  [{'label': 'POSITIVE', 'score': 0.921213686466217}]
#
#
#
# "The modern data stack is messy and complicated"—so @prukalpa put together a very useful beginner's guide (with books, podcasts, blogs, and more) to help new teammates stay on top of data science news and trends.  https://t.co/P6NCuNnqDT
#  [{'label': 'NEGATIVE', 'score': 0.9154525995254517}]
#
#
#
# "Failure to consider reproducibility beforehand could sequel several repercussions further in development." @kpwritescode zooms in on the importance of reproducible machine learning pipelines.  https://t.co/dTXr03BV2F
#  [{'label': 'POSITIVE', 'score': 0.6984821557998657}]
#
#
#
# Linear regression and logistic regression are the two most widely used statistical models and act like master keys, unlocking the secrets hidden in datasets. Learn all about these methods in our course.  https://t.co/Vhs0kG4Zib #python #datascience  https://t.co/YwiCSScqy2
#  [{'label': 'POSITIVE', 'score': 0.9697263240814209}]
#
#
#
# "The main developers and deployers of AI are focused on profit-seeking and social control [...]."  When @pewresearch asked 602 tech leaders, researchers, and activists about the prospects of #AIEthics, the responses they were mostly pessimistic. #TDSPick  https://t.co/04hqW7xrQ2
#  [{'label': 'NEGATIVE', 'score': 0.9896277189254761}]
#
#
#
# Discover how Dataiku can drastically reduce total cost of ownership for data science initiatives and help your organization become a more intelligent enterprise. |  https://t.co/v3v9mAtUWS #DataScience #EnterpriseAI #TCO
#  [{'label': 'NEGATIVE', 'score': 0.9600724577903748}]
#
#
#
# Did you ever get stuck trying to have your conda environment show up in Jupyter Notebooks? @benbogart proposes three methods to get it done.  https://t.co/U0SoMPEX2Y
#  [{'label': 'NEGATIVE', 'score': 0.9954997897148132}]
#
#
#
# Your weekend must-reads are here—including @pandeyparul on automating the structure of your projects, @prukalpa on implementing a brand-new data warehouse, and @mgsosna on the surprising similarities between algorithms and schools of fish.  https://t.co/Cu9GF9pEhL
#  [{'label': 'NEGATIVE', 'score': 0.5605468153953552}]
#
#
#
# 📅 Data-focused role with @NationalTheatre is closing soon 📅  As Head of Data &amp; Insight you'll combine strategic thinking with hands-on implementation, with aspects of data science, project management, IT development &amp; leading a team. Ends 21/06  ➡️ https://t.co/ilZnruKm8Y
#  [{'label': 'POSITIVE', 'score': 0.9668831825256348}]
#
#
#
# We need to stop confusing statistical significance with scientific significance, says @ericjdaza in his post on the language we use around statistics—and how it frames value, truth, and decision-making.  https://t.co/ErXXpN5h2k
#  [{'label': 'POSITIVE', 'score': 0.8672057390213013}]
#
#
#
# But whatever happens we should all admit that data loggers are never actually going to be used by the majority of science teachers ;)
#  [{'label': 'NEGATIVE', 'score': 0.9995481371879578}]
#
#
#
# "The main developers and deployers of AI are focused on profit-seeking and social control [...]."   @pewresearch asked 602 tech leaders, researchers, and activists about the prospects of #AIEthics. The responses were largely pessimistic. #TDSPick  https://t.co/04hqW7xrQ2
#  [{'label': 'NEGATIVE', 'score': 0.9783478379249573}]
#
#
#
# Are you new to your data science or analytics role? Here are some principles and strategies  to create a scheduled query based on your specific scenario, courtesy of Astandri Koesriputranto.  https://t.co/OTliNhqXxq
#  [{'label': 'POSITIVE', 'score': 0.7993869185447693}]
#
#
#
# CBSE has collaborated with which tech giant to introduce Coding and Data Science as new subjects in the 2021-22 academic session?  A. IBM B. Google C. Microsoft D. TCS  Reply Answer 📝  Please ❤️ &amp; Retweet 🔃  #currentaffairs #mcq #gk #generalawareness #bestcurrentaffairs
#  [{'label': 'NEGATIVE', 'score': 0.9803942441940308}]
#
#
#
# In his latest project, @brain_robber leveraged time series forecasting to predict solar irradiation—which has potential to help solar-energy generation become more efficient.  https://t.co/48WxeAqSfk
#  [{'label': 'POSITIVE', 'score': 0.9846168756484985}]
#
#
#
# America's #COVID19 evidence-based response, leadership that respects data, scientists, and funds science have led a turnaround in the country. India needs a course correction too, @iimb_official writes  https://t.co/k5y9Yr3mN1
#  [{'label': 'NEGATIVE', 'score': 0.9332712888717651}]
#
#
#
# You can't prepare for every single coding interview question, but possessing a solid, versatile approach for tackling them could be immensely helpful. Here's how @_aqeelanwar recommends you prepare for your next round.  https://t.co/r1DnSPRNY1
#  [{'label': 'POSITIVE', 'score': 0.9982819557189941}]
#
#
#
# Amid a pandemic-induced global digital transformation drive, TCS, Infosys and Wipro train are training client workforces in app development, data science, artificial intelligence, &amp; industrial IoT, report @Alnoor_ET &amp; @Anandi_ET   https://t.co/3BrdiCaada
#  [{'label': 'NEGATIVE', 'score': 0.9820514917373657}]
#
#
#
# #Data has shown that the Whakaari volcano had released certain telltale gases before erupting. Using high-resolution #satellite data and #computer algorithms, #scientists can improve volcano monitoring. #science #earth    https://t.co/vbRGXPP5G3
#  [{'label': 'NEGATIVE', 'score': 0.9791891574859619}]
#
#
#
# Ontario's COVID-19 Science Advisory Table says they need more data on how Step 1 of reopening has impacted the province before moving on.   https://t.co/q0zFqFTiy4
#  [{'label': 'NEGATIVE', 'score': 0.9979958534240723}]
#
#
#
# Looking for a statistics refresher? Join Luís Roque in the latest from his weekly series—in this post, he covers sampling distributions with Python.  https://t.co/h0cX3qtuHB
#  [{'label': 'NEGATIVE', 'score': 0.9825156927108765}]
#
#
#
# When and how should you move from Pandas to Spark? @sanket107 explains what it takes to make an informed decision.  https://t.co/3GLv7KLDtL
#  [{'label': 'NEGATIVE', 'score': 0.9291927218437195}]
#
#
#
# A volcano that spewed fire last month in Congo has since settled down, but a new flashpoint has erupted at the geophysical observatory that monitors it, with accusations that “neocolonial” partners in Europe deprived them of key data.  https://t.co/KqqTwDwhbt
#  [{'label': 'NEGATIVE', 'score': 0.9920037388801575}]
#
#
#
# Excellent interview. Data. Science. Facts!
#  [{'label': 'POSITIVE', 'score': 0.9998608827590942}]
#
#
#
# @HeroineRipley Yes, I do, it happened before the clinical trial data was out, while Trump was pushing a dangerous unproven medication and leaning on the FDA to make unjustified approvals.  Then the data came out, was reviewed, and Dems went with the science—while the GOP pushed misinformation.
#  [{'label': 'NEGATIVE', 'score': 0.9598445892333984}]
#
#
#
# Sheriff Knezovich: Stop Using "Junk Science" to bash/devalue law enforcement.  #Sheriff -“Junk Science” math used to try &amp; prove false narrative-why Facts/Real Science should be used when comparing #police shootings &amp; other #LawEnforcement data.  https://t.co/kwDB5oUBSZ   #Spokane  https://t.co/4so3MWKduC
#  [{'label': 'NEGATIVE', 'score': 0.9993434548377991}]
#
#
#
# Join @IoTCommunity at the @IoTSlam Live 2021 event, June 24 in New Orleans, to validate &amp; enhance your #IoT, #Edge, #AI, and #5G strategies:  https://t.co/L3ehy4TkZF  ————— #IoTPL #IIoT #IoTCommunity #EdgeAI #DigitalTransformation #Industry40 #BigData #DataScience #EdgeComputing  https://t.co/7SDddU3w3N
#  [{'label': 'POSITIVE', 'score': 0.915677547454834}]
#
#
#
# White men who had Black neighbors early in life were more likely to be registered Democrats more than 70 years later, according to an analysis of linked administrative data. The findings were consistent across regions of the U.S. @ScienceAdvances  https://t.co/1cZsTgbHth  https://t.co/YJ8GCiBMra
#  [{'label': 'POSITIVE', 'score': 0.9920591115951538}]
#
#
#
# @clairernak @shkempticismr @MonsieurCS @DLaVa84 @RobertHarding Thanks for the retweets and good luck with your careers in journalism and data science!
#  [{'label': 'POSITIVE', 'score': 0.999573290348053}]
#
#
#
# With machine learning pipelines becoming increasingly complex (if not downright clunky), @andrejusb wanted to implement a streamlined end-to-end solution. Here's what he came up with.  https://t.co/TpLe5RPjRo
#  [{'label': 'NEGATIVE', 'score': 0.979704737663269}]
#
#
#
# Since #datascience is only as useful as the systems it powers, everyone in the #tech ecosystem needs to think like a data scientist to get maximum mileage from their data science engagement. Here are three questions to help hone your data science thinking.  https://t.co/tt5xWaSrmS
#  [{'label': 'NEGATIVE', 'score': 0.9833426475524902}]
#
#
#
# [From the archives:] “The most surprising result was really seeing how connected the data was," said Benjamin Squire, Senior Data Scientist at @MeredithCorp     https://t.co/nLXJzVvl4t #DataScience #GraphDatabases
#  [{'label': 'NEGATIVE', 'score': 0.8740106225013733}]
#
#
#
# Jupyter Notebooks are everywhere, which might explain why they sometimes get a bad rep among data scientists. @MaartenGr comes in the service's defense, highlighting its benefits—and showing ways you can supercharge it to improve your workflows.  https://t.co/Bx1cK9bPPX
#  [{'label': 'NEGATIVE', 'score': 0.9615280032157898}]
#
#
#
# If you're view of #1A extends only to your view, no thanks.  I believe in the marketplace of ideas.  Good science and good data make for good decisions.  Human resources are our most important resource.  This aint complicated.
#  [{'label': 'POSITIVE', 'score': 0.98757404088974}]
#
#
#
# At @AeroFarms, #horticulture intersects with #genetics, #foodsafety, #datascience, and #nutrition, giving us the distinct capability to understand #plantbiology &amp; harvest the best tasting greens with fewer resources. Shop our greens  https://t.co/ORLD20lztY.  #VerticalFarming #NJ  https://t.co/H2VgThZx31
#  [{'label': 'POSITIVE', 'score': 0.9792129397392273}]
#
#
#
# The line separating data scientists from data engineers is hazy and shifts from one company to another. @snr14 argues that to find success as a data scientist, you "should possess the ability and skills to handle some data engineering tasks."  https://t.co/AaFGejpxUy
#  [{'label': 'POSITIVE', 'score': 0.6882851719856262}]
#
#
#
# I'm not even talking about his vaccine decision, but that tweet. As for the former...the way I see it...  1. Choosing to get vaccinated or not is your personal choice.  2. But you can't get mad when that choice impacts you based on decisions others have made around science/data.
#  [{'label': 'NEGATIVE', 'score': 0.9607469439506531}]
#
#
#
# Many data scientists say networking is key for finding a great job, but... how does one actually network? What does it entail, and what things should you stay mindful of? Isabelle Flückiger lays it all out in a detailed, step-by-step guide.  https://t.co/zYFpk4Wt9o
#  [{'label': 'POSITIVE', 'score': 0.9937207698822021}]
#
#
#
# yet more data,science on how Ivermectin works. main thing is it takes up the Ace 2 parking spot where covid likes to park, thus inhibits binding.  https://t.co/t4H5LQn01U
#  [{'label': 'NEGATIVE', 'score': 0.9970670342445374}]
#
#
#
# A polyglot scientist tries Topcoder and becomes development champion multiple times, data science copilot and MVP. Learn more about birdofpreyru by joining us:  https://t.co/GTtQ4PJmJf #Topcoder #Topcodernation #AMA  https://t.co/SrMeuoN3nE
#  [{'label': 'POSITIVE', 'score': 0.8478241562843323}]
#
#
#
# Learn how #datascience has become an important part of #business with this free #openSAP #MOOC  https://t.co/PsrmFNPLlU  https://t.co/RYGCP528Sc
#  [{'label': 'NEGATIVE', 'score': 0.9831673502922058}]
